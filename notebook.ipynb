# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. Genre-based Recommendation Engine
# 1. Determine features of a song, and which columns are considered obsolete for decision-making
# 2. Cluster based on the predetermined features to deterime `genre`
# 3. Analyze the data based on the new clusters and label them as genres. List all the unique genres.
# 4. Apply PCA in order to project the newfound clusters into two-dimensional space.
# 5. Take an input which is one of the unique genres in step 3. Return random 10 songs of that genre.

# %% [markdown]
# ## Analyzing the sourced raw data
# We import the data and see the columns in the .csv file, as well as its corresponding data types (string or numerics). Via the Spotify official developer website, we can understand and take not the overall representation for each column (i.e. what each column means and how they relate to each other)

# %%
raw_data = pd.read_csv("data/data.csv")
raw_data.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
raw_data.info() # To see whether the numerical data are already represented as numerics and not strings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169909 entries, 0 to 169908
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      169909 non-null  float64
#  1   artists           169909 non-null  object
#  2   danceability      169909 non-null  float64
#  3   duration_ms       169909 non-null  int64
#  4   energy            169909 non-null  float64
#  5   explicit          169909 non-null  int64
#  6   id                169909 non-null  object
#  7   instrumentalness  169909 non-null  float64
#  8   key               169909 non-null  int64
#  9   liveness          169909 non-null  float64
#  10  loudness          169909 non-null  float64
#  11  mode              169909 non-null  int64
#  12  name              169909 non-null  object
#  13  popularity        169909 non-null  int64
#  14  release_date      169909 non-null  object
#  15  speechiness       169909 non-null  float64
#  16  tempo             169909 non-null  float64
#  17  valence           169909 non-null  float64
#  18  year              169909 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.6+ MB

# %% [markdown]
# From [this page](https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/), we can derive the meaning for each column above. I'll write them down in this cell so we won't need to look back and forth on that page.
# 1. `Acousticness` represents a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# 2. `Danceability` represents how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. 1.0 is most danceable.
# 3. `Energy` represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. 1.0 is most energetic
# 4. `Instrumentalness` represents the instrumental frequency in the track. 1.0 represents tracks with no vocals.
# 5. `Liveness` represents the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live
# 6. `Loudness` represents the loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Values typical range between -60 and 0 db.
# 7. `Speechiness` represents the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 are tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks
# 8. `Valence` represents the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric).
# 9. `Tempo` represents the overall estimated tempo of a track in beats per minute (BPM).
# 10. `Mode` 0 = Minor, 1 = Major
# 11. `Explicit` 0 = No explicit content, 1 = Explicit content\
# 12. `Key` represents the estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# ---
# Despite the data has been cleaned, we can double-check whether a column has any missing `NaN` data. It should return the column name along with the number of missing data besides it.

# %%
for colname in raw_data.columns.tolist():
    print("Column {}".format(colname) + " has {} missing values.".format(raw_data[colname].isnull().sum()))
# Out:
# Column acousticness has 0 missing values.
# Column artists has 0 missing values.
# Column danceability has 0 missing values.
# Column duration_ms has 0 missing values.
# Column energy has 0 missing values.
# Column explicit has 0 missing values.
# Column id has 0 missing values.
# Column instrumentalness has 0 missing values.
# Column key has 0 missing values.
# Column liveness has 0 missing values.
# Column loudness has 0 missing values.
# Column mode has 0 missing values.
# Column name has 0 missing values.
# Column popularity has 0 missing values.
# Column release_date has 0 missing values.
# Column speechiness has 0 missing values.
# Column tempo has 0 missing values.
# Column valence has 0 missing values.
# Column year has 0 missing values.

# %%
df = raw_data[['id', 'name', 'artists', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'explicit', 'key', 'liveness', 'loudness', 'mode', 'popularity','speechiness', 'tempo', 'valence']]

# %% [markdown]
# ## Begin to cluster the data
# Before we instantiate the clustering on our feature set, we need to determine which value of k is optimal using the elbow method.

# %% [raw]
# from sklearn.cluster import KMeans # Clustering library
# %matplotlib inline
#
# features = df[list(df.columns)[3:]]
# distortions = []
#
# k_values = list(np.arange(10, 40, 5))
# for k in k_values:
#     kmeanModel = KMeans(n_clusters=k)
#     kmeanModel.fit(features)
#     distortions.append(kmeanModel.inertia_)
# plt.figure(figsize=(16,8))
# plt.plot(k_values, distortions, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Distortion')
# plt.title('The Elbow Method showing the optimal k')
# plt.show()
# # Change cell type to `code` to see the distortions corresponding with the k values.

# %% [markdown]
# We can see that the elbow resides somewhere between `k = 20` clusters. Therefore, we should choose 20 as the number of unique `genres`

# %%
from sklearn.cluster import KMeans # Clustering library
# %matplotlib inline

features = df[list(df.columns)[3:]]
distortions = []

plt.clf()
k = 20
k_means = KMeans(init = "k-means++", n_clusters = k, n_init = 12) # Run 12 times with different centroid seeds
k_means.fit(features.values)
# Out:
# KMeans(n_clusters=20, n_init=12)

# %%
temp = pd.DataFrame(k_means.labels_)
df = pd.concat([df, temp], axis=1)
df.rename(columns={0: "cluster"}, inplace=True)
df.head()
# Out:
#                        id                                           name  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD                    Singende Bataillone 1. Teil
# 1  6KuQTIu1KoTTkLXKrwlLPV       Fantasiestücke, Op. 111: Più tosto lento
# 2  6L63VW0PibdM1HDSBoqnoM                 Chapter 1.18 - Zamek kaniowski
# 3  6M94FkXd15sOAOQYRnWPN8  Bebamos Juntos - Instrumental (Remasterizado)
# 4  6N6tiFZ9vLTSOIxkj8qKrd    Polonaise-Fantaisie in A-Flat Major, Op. 61
#
#                                     artists  acousticness  danceability  \
# 0                       ['Carl Woitschach']         0.995         0.708
# 1  ['Robert Schumann', 'Vladimir Horowitz']         0.994         0.379
# 2                   ['Seweryn Goszczyński']         0.604         0.749
# 3                      ['Francisco Canaro']         0.995         0.781
# 4  ['Frédéric Chopin', 'Vladimir Horowitz']         0.990         0.210
#
#    energy  instrumentalness  explicit  key  liveness  loudness  mode  \
# 0  0.1950             0.563         0   10    0.1510   -12.428     1
# 1  0.0135             0.901         0    8    0.0763   -28.454     1
# 2  0.2200             0.000         0    5    0.1190   -19.924     0
# 3  0.1300             0.887         0    1    0.1110   -14.734     0
# 4  0.2040             0.908         0   11    0.0980   -16.829     1
#
#    popularity  speechiness    tempo  valence  cluster
# 0           0       0.0506  118.469   0.7790       12
# 1           0       0.0462   83.972   0.0767        9
# 2           0       0.9290  107.177   0.8800       12
# 3           0       0.0926  108.003   0.7200       12
# 4           1       0.0424   62.149   0.0693        9

# %%
import ast
df_new = df.copy(deep=True)

# %%
df_new['artists'] = df_new['artists'].apply(lambda x: (ast.literal_eval(x)[0]))

# %%
for i in range(k):
    to_print = df_new[df_new['cluster'] == i]
    print("Cluster {}".format(i))
    display(to_print.head())
    print("----------------------------------------------------------------------------------------------------")
# Out:
# Cluster 0
#                           id                                    name  \
# 1763  6M2da2eRNj08QJ4TT5vYuU  The Man I Love - 1995 Digital Remaster
# 1764  6SEDXcebrNoYClqPORDe91                            All Too Soon
# 1770  76aRzC9R2XaYOY09k3JfDX                             Easy Living
# 1771  79uBIicCUMDSRGomaKI79J                                Metaphor
# 1777  0O6GI9vbKCe9kj5hj4hSBf        Right String but the Wrong Yo Yo
#
#               artists  acousticness  danceability  energy  instrumentalness  \
# 1763        Peggy Lee         0.968         0.262  0.2190          0.004390
# 1764  Ella Fitzgerald         0.854         0.429  0.1570          0.000000
# 1770       John Lewis         0.994         0.526  0.0872          0.003940
# 1771     Yusef Lateef         0.847         0.448  0.2020          0.041200
# 1777     Carl Perkins         0.284         0.613  0.8880          0.000051
#
#       explicit  key  liveness  loudness  mode  popularity  speechiness  \
# 1763         0   10     0.158   -13.534     0          19       0.0323
# 1764         0    1     0.104   -14.926     1          16       0.0354
# 1770         0    8     0.130   -13.066     1          18       0.0446
# 1771         0    2     0.107   -19.357     0          17       0.0429
# 1777         0    0     0.238    -7.684     1          16       0.0628
#
#         tempo  valence  cluster
# 1763  112.194    0.118        0
# 1764  125.212    0.209        0
# 1770  129.201    0.401        0
# 1771  120.777    0.281        0
# 1777  117.759    0.889        0
# ----------------------------------------------------------------------------------------------------
# Cluster 1
#                          id  \
# 33   6Z6DJ8L7WMy2WHbXe3jR9I
# 81   6yanEXQBzoNKlWJzKGBpsb
# 101  3yZj8i9TwsWAVmBWKdMbaa
# 114  40jiorcB4ujhNCJEM3NYRz
# 118  41fXcqGebIUYOFQvDzqLJG
#
#                                                   name             artists  \
# 33   A Shropshire Lad: Oh Fair Enough are Sky and P...  George Butterworth
# 81   Reaching for Someone (And Not Finding Anyone T...       Paul Whiteman
# 101                           Cobardia - Remasterizado     Ignacio Corsini
# 114            Cantando Bajo la Lluvia - Remasterizado    Francisco Canaro
# 118                         A Lo Lejos - Remasterizado    Francisco Canaro
#
#      acousticness  danceability  energy  instrumentalness  explicit  key  \
# 33          0.987         0.238  0.0324          0.000986         0    7
# 81          0.993         0.523  0.0867          0.124000         0   10
# 101         0.991         0.545  0.1330          0.444000         0    7
# 114         0.989         0.445  0.2880          0.758000         0    2
# 118         0.990         0.518  0.4620          0.850000         0    4
#
#      liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 33      0.112   -24.361     0           0       0.0541  172.321   0.0379
# 81      0.140   -17.528     1           1       0.0707  161.687   0.6970
# 101     0.115   -20.530     0           0       0.1270  185.062   0.6910
# 114     0.111    -8.925     1           0       0.0699  205.423   0.6970
# 118     0.157    -9.632     0           0       0.3770  178.880   0.6960
#
#      cluster
# 33         1
# 81         1
# 101        1
# 114        1
# 118        1
# ----------------------------------------------------------------------------------------------------
# Cluster 2
#                           id                name           artists  \
# 2782  3M0nozpvaNSj5WOF5JeW45      Ride Your Pony      Betty Harris
# 2845  4J2xMy0kakU9sAin1uppxb            La Balsa         Los Gatos
# 2963  6SsQ4eeyzgJirHaWABOK9Q           Désormais  Charles Aznavour
# 3022  5gpQ5GGP8u7GETtKIlGPVY     Now and Forever       Jimmy Cliff
# 3028  22zbgTMLuj0sNFLxCJGdHR  Jumpin' Jack Flash    Thelma Houston
#
#       acousticness  danceability  energy  instrumentalness  explicit  key  \
# 2782        0.0895         0.694   0.691           0.00387         0   10
# 2845        0.4030         0.506   0.611           0.00000         0   11
# 2963        0.5700         0.438   0.687           0.00000         0    0
# 3022        0.1230         0.555   0.474           0.00000         0    5
# 3028        0.0767         0.525   0.706           0.43200         0    8
#
#       liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 2782     0.293    -7.499     0          41       0.0530  123.244    0.961
# 2845     0.190    -4.977     1          46       0.0313  125.925    0.646
# 2963     0.140    -5.968     0          45       0.0448  123.178    0.460
# 3022     0.132    -8.646     1          38       0.0277  123.323    0.316
# 3028     0.176    -9.125     1          35       0.0345  132.902    0.840
#
#       cluster
# 2782        2
# 2845        2
# 2963        2
# 3022        2
# 3028        2
# ----------------------------------------------------------------------------------------------------
# Cluster 3
#                           id  \
# 1682  5fDFyReOWEeALWPzGYu4SM
# 1754  5aWJ0sKEfLQh5VHGxfpBwO
# 1755  5gGq4KxuYuivZWQpUi0HXT
# 1758  5soXG9VjJxo6RQNQ2eNtpg
# 1760  62CB0noXueC3vEE1wdWh8h
#
#                                                    name  \
# 1682                          Jumps, Giggles And Shouts
# 1754       6 Little Preludes: No. 4 in D Major, BWV 936
# 1755                      Doin' My Time (2017 Remaster)
# 1758  Italian Concerto in F Major, BWV 971: I. [ ] -...
# 1760  9 Little Preludes, BWV 924-932: Praeludium in ...
#
#                            artists  acousticness  danceability  energy  \
# 1682  Gene Vincent & His Blue Caps         0.141         0.591   0.803
# 1754         Johann Sebastian Bach         0.993         0.424   0.206
# 1755                   Johnny Cash         0.121         0.617   0.587
# 1758         Johann Sebastian Bach         0.980         0.314   0.351
# 1760         Johann Sebastian Bach         0.995         0.609   0.340
#
#       instrumentalness  explicit  key  liveness  loudness  mode  popularity  \
# 1682           0.00000         0    7    0.2040    -9.660     1          15
# 1754           0.90300         0    2    0.1950   -25.727     1          18
# 1755           0.00156         0   10    0.2090   -13.291     0          14
# 1758           0.82400         0    5    0.0775   -19.263     1          20
# 1760           0.88400         0    5    0.1950   -19.569     1          20
#
#       speechiness    tempo  valence  cluster
# 1682       0.0584   96.198    0.856        3
# 1754       0.0515  100.427    0.961        3
# 1755       0.0315  105.613    0.735        3
# 1758       0.0383   95.357    0.905        3
# 1760       0.0752   91.700    0.974        3
# ----------------------------------------------------------------------------------------------------
# Cluster 4
#                           id  \
# 1695  6qdHpkWJJa2tAR59v8XkfR
# 1734  1fEepJX6lz8fqhDRsNxkQp
# 1762  6GmTz8aCMthyvw8OkdbDdF
# 1766  6Z19hWp496a19Us6tbVDWB
# 1767  6nzeMuNY6K841H1P193VAX
#
#                                                    name               artists  \
# 1695                                              Lover       Ella Fitzgerald
# 1734                                           Overture  Antônio Carlos Jobim
# 1762                                       Sonny's Mood           Sonny Clark
# 1766  Under a Blanket of Blue (with Paul Weston & Hi...             Doris Day
# 1767                       My Bucket's Got A Hole In It       Louis Armstrong
#
#       acousticness  danceability  energy  instrumentalness  explicit  key  \
# 1695         0.621         0.428  0.4760          0.000000         0    2
# 1734         0.871         0.221  0.2690          0.173000         0    9
# 1762         0.846         0.544  0.3440          0.000646         0    5
# 1766         0.944         0.348  0.0596          0.000527         0    7
# 1767         0.793         0.524  0.2280          0.000000         0    9
#
#       liveness  loudness  mode  popularity  speechiness   tempo  valence  \
# 1695     0.136    -6.931     1          15       0.0514  82.664    0.464
# 1734     0.174   -10.066     0          17       0.0340  80.475    0.169
# 1762     0.335   -11.963     0          16       0.0426  75.166    0.573
# 1766     0.124   -18.770     1          18       0.0355  66.479    0.146
# 1767     0.210    -9.553     0          16       0.0351  80.105    0.340
#
#       cluster
# 1695        4
# 1734        4
# 1762        4
# 1766        4
# 1767        4
# ----------------------------------------------------------------------------------------------------
# Cluster 5
#                           id                                        name  \
# 4192  1kxPRJGVKGqjJM7BB44p0p                          Errol - Remastered
# 4640  5fu5vl7owT5ny0ry2Bema2     Si No Fuera Por... - Remasterizado 2007
# 4689  2ePNAnihorbU5j4jzzfKJT                     Las Curvas de Esa Chica
# 5138  751bsmv3KNPrytbCUdzQJN                                  Via con me
# 5139  7A4qkJulbEMvveTLvj7Tbo  The Weeping Song - 2010 Remastered Version
#
#                         artists  acousticness  danceability  energy  \
# 4192           Australian Crawl        0.0414         0.613   0.772
# 4640                Soda Stereo        0.0183         0.605   0.855
# 4689                     Mecano        0.2620         0.655   0.833
# 5138                Paolo Conte        0.7990         0.669   0.425
# 5139  Nick Cave & The Bad Seeds        0.2040         0.416   0.723
#
#       instrumentalness  explicit  key  liveness  loudness  mode  popularity  \
# 4192          0.000000         0    0     0.240    -6.971     1          56
# 4640          0.004040         0    0     0.242    -5.250     1          47
# 4689          0.000041         0    5     0.163    -6.866     1          48
# 5138          0.011100         0    5     0.152   -18.404     1          50
# 5139          0.000005         0    7     0.116    -9.793     0          48
#
#       speechiness    tempo  valence  cluster
# 4192       0.0422  164.825    0.785        5
# 4640       0.0470  172.275    0.694        5
# 4689       0.1670  164.197    0.817        5
# 5138       0.1400  165.314    0.700        5
# 5139       0.1360  170.300    0.719        5
# ----------------------------------------------------------------------------------------------------
# Cluster 6
#                         id                                               name  \
# 10  6QBInZBkQNIQYU9gGzT5l4  Piano Sonata No. 2 in B-Flat Minor, Op. 36: I....
# 27  6WRmg6x1bYjHxzeMCfKguB                   Scherzo No. 1 in B Minor, Op. 20
# 35  6ZWi1fuonJCUlt4p6o9Uzs                                  La Noce À Rebecca
# 39  6bKJYhoaWIohnhspidbdW7                     Chapter 2.11 - Zamek kaniowski
# 62  6oZyWbbisoG8jOunmpPH40                                   Country Blues #1
#
#                 artists  acousticness  danceability  energy  instrumentalness  \
# 10  Sergei Rachmaninoff         0.994         0.376  0.0719          0.883000
# 27      Frédéric Chopin         0.991         0.380  0.1190          0.890000
# 35            Perchicot         0.989         0.769  0.4420          0.000001
# 39  Seweryn Goszczyński         0.777         0.738  0.2820          0.000000
# 62            Taj Mahal         0.872         0.571  0.2040          0.779000
#
#     explicit  key  liveness  loudness  mode  popularity  speechiness    tempo  \
# 10         0   10    0.1960   -21.849     0           0       0.0352  141.390
# 27         0   11    0.0601   -21.255     1           0       0.0389  132.005
# 35         0    2    0.1670   -12.697     0           0       0.2730  132.125
# 39         0    1    0.2900   -16.556     1           0       0.9520  140.612
# 62         0    6    0.1970   -18.610     1           0       0.0328  129.289
#
#     valence  cluster
# 10   0.0393        6
# 27   0.1800        6
# 35   0.9340        6
# 39   0.7030        6
# 62   0.0932        6
# ----------------------------------------------------------------------------------------------------
# Cluster 7
#                           id  \
# 1977  7kkIAIAKqHp3lb1XhPUG6x
# 2005  3UBG6YnD80FP1RiC4uavGj
# 2148  22dqPEditHWH5vQ8S9pC8q
# 2317  5dILFohd0MWsM5a1ueCiBO
# 2366  71TdR127wNt70AwcpLP4aT
#
#                                                    name           artists  \
# 1977                          Broto Legal (I'm In Love)    Sérgio Murillo
# 2005                                    Beyond The Reef      Billy Vaughn
# 2148  El Amor Es una Cosa Esplendorosa (Love Is a Ma...    Enrique Guzman
# 2317                   Vilaines filles, mauvais garçons  Serge Gainsbourg
# 2366                                 Shut Down (Stereo)    The Beach Boys
#
#       acousticness  danceability  energy  instrumentalness  explicit  key  \
# 1977        0.6620         0.716   0.505          0.000773         0   11
# 2005        0.7780         0.319   0.301          0.403000         0    9
# 2148        0.7200         0.165   0.436          0.000000         0    2
# 2317        0.3320         0.491   0.766          0.000005         0    0
# 2366        0.0545         0.589   0.676          0.001850         0    8
#
#       liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 1977    0.0318    -9.069     1          24       0.4950  168.302    0.907
# 2005    0.1330   -11.733     0          22       0.0294  159.097    0.463
# 2148    0.2250    -7.921     1          27       0.0341  175.835    0.314
# 2317    0.4480   -10.684     1          25       0.0432  165.599    0.904
# 2366    0.0442   -10.770     1          17       0.0475  159.892    0.979
#
#       cluster
# 1977        7
# 2005        7
# 2148        7
# 2317        7
# 2366        7
# ----------------------------------------------------------------------------------------------------
# Cluster 8
#                           id                     name              artists  \
# 5375  5lSOVaPDk7x9Ey6c9DqGZx            Sweet Harmony          The Beloved
# 5483  2FHnN5ELL83TGbtXMDzoiJ            I Like Chopin               Gazebo
# 5676  7BZLNqU7zChzcnSo6ETJ5l  Rotterdam (Or Anywhere)  The Beautiful South
# 5683  5yIVcrwQXdIlDgTMc8pa6z                  Contigo       Joaquín Sabina
# 5830  0tTbk9bpoFRDa19eVghS4d                   Caruso    Luciano Pavarotti
#
#       acousticness  danceability  energy  instrumentalness  explicit  key  \
# 5375        0.0144         0.573   0.837          0.088900         0   10
# 5483        0.5770         0.779   0.635          0.000258         0    2
# 5676        0.3270         0.724   0.585          0.000002         0    0
# 5683        0.0309         0.490   0.418          0.000020         0    2
# 5830        0.8350         0.332   0.230          0.000045         0    7
#
#       liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 5375    0.0544    -8.352     0          57       0.0337  101.590    0.796
# 5483    0.2150    -8.028     0          59       0.0282  108.018    0.530
# 5676    0.1390    -7.680     1          60       0.0312  108.114    0.525
# 5683    0.0615   -10.773     1          62       0.0572   98.507    0.226
# 5830    0.1070   -12.146     0          55       0.0338   99.573    0.215
#
#       cluster
# 5375        8
# 5483        8
# 5676        8
# 5683        8
# 5830        8
# ----------------------------------------------------------------------------------------------------
# Cluster 9
#                        id                                            name  \
# 1  6KuQTIu1KoTTkLXKrwlLPV        Fantasiestücke, Op. 111: Più tosto lento
# 4  6N6tiFZ9vLTSOIxkj8qKrd     Polonaise-Fantaisie in A-Flat Major, Op. 61
# 5  6NxAf7M8DNHOBTmEd3JSO5                     Scherzo a capriccio: Presto
# 6  6O0puPuyrxPjDTHDUgsWI7  Valse oubliée No. 1 in F-Sharp Major, S. 215/1
# 9  6PrZexNb16cabXR8Q418Xc                   Chapter 1.3 - Zamek kaniowski
#
#                artists  acousticness  danceability  energy  instrumentalness  \
# 1      Robert Schumann         0.994         0.379  0.0135             0.901
# 4      Frédéric Chopin         0.990         0.210  0.2040             0.908
# 5    Felix Mendelssohn         0.995         0.424  0.1200             0.911
# 6          Franz Liszt         0.956         0.444  0.1970             0.435
# 9  Seweryn Goszczyński         0.846         0.674  0.2050             0.000
#
#    explicit  key  liveness  loudness  mode  popularity  speechiness   tempo  \
# 1         0    8    0.0763   -28.454     1           0       0.0462  83.972
# 4         0   11    0.0980   -16.829     1           1       0.0424  62.149
# 5         0    6    0.0915   -19.242     0           0       0.0593  63.521
# 6         0   11    0.0744   -17.226     1           0       0.0400  80.495
# 9         0    9    0.1700   -20.119     1           0       0.9540  81.249
#
#    valence  cluster
# 1   0.0767        9
# 4   0.0693        9
# 5   0.2660        9
# 6   0.3050        9
# 9   0.7590        9
# ----------------------------------------------------------------------------------------------------
# Cluster 10
#                         id                                               name  \
# 11  6QIONtzbQCbnmWNwn0H1yT     Piano Sonata No. 2, Op. 35: IV. Finale. Presto
# 12  6QgdUySTRGVkNo3KwbHpK3  Piano Sonata in E-Flat Minor, Op. 26: III. Ada...
# 22  6VUm7Dg5sufmG01IYcoJE3           Andante spianato in E-Flat Major, Op. 22
# 31  6XoyWGdCJwFaJV1Pnmphwr                      Por una Mujer - Remasterizado
# 74  6v13FCz4z385EbNyPaXYCU  Piano Sonata in E-Flat Minor, Op. 26: II. Alle...
#
#             artists  acousticness  danceability  energy  instrumentalness  \
# 11  Frédéric Chopin         0.989         0.170  0.0823            0.9110
# 12    Samuel Barber         0.990         0.359  0.0435            0.8990
# 22  Frédéric Chopin         0.975         0.277  0.0900            0.9490
# 31  Ignacio Corsini         0.995         0.531  0.1240            0.0168
# 74    Samuel Barber         0.987         0.242  0.1490            0.8770
#
#     explicit  key  liveness  loudness  mode  popularity  speechiness    tempo  \
# 11         0   10    0.0962   -30.107     0           1       0.0317   85.989
# 12         0    7    0.1090   -20.858     1           0       0.0424   96.645
# 22         0    7    0.1250   -26.188     1           0       0.0316  105.031
# 31         0    2    0.1180   -23.243     1           0       0.0711  101.902
# 74         0    0    0.1340   -26.742     1           0       0.0369   88.188
#
#     valence  cluster
# 11    0.346       10
# 12    0.042       10
# 22    0.168       10
# 31    0.555       10
# 74    0.279       10
# ----------------------------------------------------------------------------------------------------
# Cluster 11
#                           id  \
# 2106  67LQpgGMjI0jnXo9lRj07C
# 2186  5zUJlRQyzxw09Jv1hDgL5h
# 2201  0Cx7w1aXcvsPBdfdND0Pju
# 2966  70gCYpuRthr9sfC3WV8g5P
# 3007  3Tz5fLDzaPYxvd5MY6gtS1
#
#                                                    name             artists  \
# 2106                                  A Volta do Boêmio    Nelson Gonçalves
# 2186                               Twist à Saint-Tropez  Les Chats Sauvages
# 2201                        Presumida (High Class Baby)       Los Teen Tops
# 2966                                        Melody Fair            Bee Gees
# 3007  On Days Like These - From "The Italian Job" So...        Quincy Jones
#
#       acousticness  danceability  energy  instrumentalness  explicit  key  \
# 2106       0.89200         0.596   0.314          0.000001         0    9
# 2186       0.00318         0.390   0.637          0.000129         0    2
# 2201       0.55600         0.571   0.751          0.000000         0    2
# 2966       0.02740         0.449   0.423          0.000000         0    2
# 3007       0.77000         0.472   0.338          0.000000         0    7
#
#       liveness  loudness  mode  popularity  speechiness   tempo  valence  \
# 2106    0.1680   -10.024     0          42       0.0290  99.442    0.599
# 2186    0.4430    -4.498     1          37       0.0273  90.328    0.681
# 2201    0.0646    -9.544     1          36       0.0585  91.002    0.966
# 2966    0.0785    -8.535     1          40       0.0239  81.187    0.453
# 3007    0.1990   -10.747     0          38       0.0260  95.899    0.310
#
#       cluster
# 2106       11
# 2186       11
# 2201       11
# 2966       11
# 3007       11
# ----------------------------------------------------------------------------------------------------
# Cluster 12
#                        id                                           name  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD                    Singende Bataillone 1. Teil
# 2  6L63VW0PibdM1HDSBoqnoM                 Chapter 1.18 - Zamek kaniowski
# 3  6M94FkXd15sOAOQYRnWPN8  Bebamos Juntos - Instrumental (Remasterizado)
# 7  6OJjveoYwJdIt76y0Pxpxw                            Per aspera ad astra
# 8  6OaJ8Bh7lsBeYoBmwmo2nh               Moneda Corriente - Remasterizado
#
#                artists  acousticness  danceability  energy  instrumentalness  \
# 0      Carl Woitschach         0.995         0.708   0.195             0.563
# 2  Seweryn Goszczyński         0.604         0.749   0.220             0.000
# 3     Francisco Canaro         0.995         0.781   0.130             0.887
# 7      Carl Woitschach         0.988         0.555   0.421             0.836
# 8     Francisco Canaro         0.995         0.683   0.207             0.206
#
#    explicit  key  liveness  loudness  mode  popularity  speechiness    tempo  \
# 0         0   10     0.151   -12.428     1           0       0.0506  118.469
# 2         0    5     0.119   -19.924     0           0       0.9290  107.177
# 3         0    1     0.111   -14.734     0           0       0.0926  108.003
# 7         0    1     0.105    -9.878     1           0       0.0474  123.310
# 8         0    9     0.337    -9.801     0           0       0.1270  119.833
#
#    valence  cluster
# 0    0.779       12
# 2    0.880       12
# 3    0.720       12
# 7    0.857       12
# 8    0.493       12
# ----------------------------------------------------------------------------------------------------
# Cluster 13
#                           id           name  \
# 4312  1y96w7WDPlwByq9aISEi6G  Barro Tal Vez
# 4617  5WeBnrDPyLhxruxVryHCkn  La Bestia Pop
# 5085  747fyAuUDG3feXRd6pILnx      Your Song
# 5352  5UkoitnvaDUSsq7cVsOdOh     Be My Baby
# 5377  5bxQHscWvyaQbm37igKP4K  La solitudine
#
#                                       artists  acousticness  danceability  \
# 4312                    Luis Alberto Spinetta        0.9380         0.392
# 4617  Patricio Rey y sus Redonditos de Ricota        0.0506         0.641
# 5085                               Elton John        0.7800         0.554
# 5352                          Vanessa Paradis        0.4470         0.731
# 5377                            Laura Pausini        0.7380         0.574
#
#       energy  instrumentalness  explicit  key  liveness  loudness  mode  \
# 4312   0.124          0.000000         0    2    0.1340   -15.154     0
# 4617   0.677          0.112000         0    7    0.0687   -10.142     1
# 5085   0.330          0.000003         0    3    0.1070   -10.866     1
# 5352   0.683          0.000005         0    0    0.1170    -8.045     1
# 5377   0.467          0.000000         0    1    0.1490    -6.374     1
#
#       popularity  speechiness    tempo  valence  cluster
# 4312          55       0.0424  122.422    0.141       13
# 4617          58       0.0327  120.666    0.896       13
# 5085          66       0.0300  128.214    0.297       13
# 5352          56       0.0294  129.062    0.963       13
# 5377          59       0.0381  131.890    0.256       13
# ----------------------------------------------------------------------------------------------------
# Cluster 14
#                           id                         name           artists  \
# 1832  0KnvDXxUgUuKIi8im5ywpE              Rocks In My Bed   Ella Fitzgerald
# 2013  4EpaFP7yN1aSWWHmAcnU5U  That's All There Is to That  Dinah Washington
# 2017  4ZD4ZwMVEPsnhCSJ3eBiQZ              East of the Sun      Paul Desmond
# 2077  2cr2rjdV2JOz1J0prTiPOG       Shake Your Money Maker      Elmore James
# 2231  34f4J8BuDUHjSYqP0EHPwA    Kahin Deep Jale Kahin Dil   Lata Mangeshkar
#
#       acousticness  danceability  energy  instrumentalness  explicit  key  \
# 1832         0.829         0.392   0.205          0.000000         0    8
# 2013         0.851         0.283   0.285          0.000122         0    8
# 2017         0.922         0.453   0.167          0.490000         0    5
# 2077         0.695         0.419   0.675          0.000320         0    2
# 2231         0.965         0.218   0.327          0.571000         0    6
#
#       liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 1832    0.0901   -13.366     1          15       0.0522  212.242    0.373
# 2013    0.1190   -14.016     1          20       0.0455  204.130    0.359
# 2017    0.1920   -18.961     0          15       0.0661  207.667    0.589
# 2077    0.0762    -5.491     1          14       0.0776  200.960    0.650
# 2231    0.3380   -11.444     0          14       0.0376  207.420    0.294
#
#       cluster
# 1832       14
# 2013       14
# 2017       14
# 2077       14
# 2231       14
# ----------------------------------------------------------------------------------------------------
# Cluster 15
#                           id  \
# 1269  19Ttq3sjIl5pW9wT7ZFfmY
# 2721  0P7TUyrm6OfIDJJKcidvnu
# 3387  2mex2o4uA69pMcLjMtyyGb
# 6930  3oKBZhpwrMiOhosXauv3lP
# 7411  7foc25ig7dibxvULPU2kBG
#
#                                                    name          artists  \
# 1269  Götterdämmerung : Act 1 : Willkommen, Gast, In...   Richard Wagner
# 2721  My Kind Of Town (Reprise) - Live At The Sands ...    Frank Sinatra
# 3387                                  Ride Me Down Easy  Waylon Jennings
# 6930                                        Ocean Waves   Crain & Taylor
# 7411                           Brown Noise - 90 Minutes    Sound Dreamer
#
#       acousticness  danceability    energy  instrumentalness  explicit  key  \
# 1269        0.9760           0.0  0.085400          0.000105         0    7
# 2721        0.0995           0.0  0.906000          0.000018         0    1
# 3387        0.7560           0.0  0.048400          0.000144         0    4
# 6930        0.9310           0.0  0.000075          0.892000         0    1
# 7411        0.1110           0.0  0.000099          0.392000         0    2
#
#       liveness  loudness  mode  popularity  speechiness  tempo  valence  \
# 1269     0.343   -21.505     1           0          0.0    0.0      0.0
# 2721     0.366    -6.227     1          22          0.0    0.0      0.0
# 3387     0.166   -18.198     1          29          0.0    0.0      0.0
# 6930     0.115   -19.703     0          47          0.0    0.0      0.0
# 7411     0.137   -21.669     1          50          0.0    0.0      0.0
#
#       cluster
# 1269       15
# 2721       15
# 3387       15
# 6930       15
# 7411       15
# ----------------------------------------------------------------------------------------------------
# Cluster 16
#                           id                                     name  \
# 3122  3yGyWqmw9eCQPdJJ6iJLWs                                 4/3/1943
# 3312  1sdW2whJr8CLa6bMA67LPQ                    Clube Da Esquina Nº 2
# 3685  5oLfyNezPv2IZdAFC9cYsh          Miss You Nights - 2001 Remaster
# 3926  1EtGuTEIAqZkBIjzY3MWCf                               オリビアを聴きながら
# 4271  3BLewreWlYMr2MbVUBfBS2  Almost With You - 2002 Digital Remaster
#
#                 artists  acousticness  danceability  energy  instrumentalness  \
# 3122        Lucio Dalla      0.891000         0.596   0.305          0.000002
# 3312  Milton Nascimento      0.440000         0.470   0.454          0.424000
# 3685      Cliff Richard      0.697000         0.284   0.250          0.000015
# 3926               Anri      0.733000         0.453   0.486          0.000002
# 4271         The Church      0.000112         0.366   0.816          0.021000
#
#       explicit  key  liveness  loudness  mode  popularity  speechiness  \
# 3122         0    0     0.192   -13.270     1          54       0.0460
# 3312         0    2     0.244   -14.921     1          45       0.0289
# 3685         0    5     0.103   -12.217     1          44       0.0328
# 3926         0    7     0.157    -7.934     1          48       0.0261
# 4271         0    0     0.136    -5.135     1          44       0.0331
#
#         tempo  valence  cluster
# 3122  134.381    0.782       16
# 3312  151.519    0.738       16
# 3685  140.908    0.217       16
# 3926  141.310    0.116       16
# 4271  152.085    0.608       16
# ----------------------------------------------------------------------------------------------------
# Cluster 17
#                           id                               name  \
# 3386  689lBKIELtWGHfsPWpR6rv     Todas las Hojas Son del Viento
# 3402  1BoLhF18bW0zMb5P4BAEEf  Help Me Make It Through the Night
# 3460  3XHm2zKyY6gcYPmF0DtBXW                        Vino Griego
# 3481  5VpZzYUnr2y3ztWREovItM                    We Said Goodbye
# 4650  5TjYiOt2CSqApOFo8gMkCb                         The Island
#
#               artists  acousticness  danceability  energy  instrumentalness  \
# 3386  Pescado Rabioso        0.6570         0.523   0.169          0.000011
# 3402        John Holt        0.2330         0.654   0.567          0.027400
# 3460       José Velez        0.2510         0.504   0.643          0.000000
# 3481     Dave Maclean        0.0366         0.381   0.469          0.003680
# 4650       Paul Brady        0.9710         0.567   0.103          0.000009
#
#       explicit  key  liveness  loudness  mode  popularity  speechiness  \
# 3386         0    0    0.1150   -14.107     1          54       0.0403
# 3402         0    4    0.3570    -8.766     1          44       0.0553
# 3460         0    5    0.2230    -4.206     1          45       0.0267
# 3481         0    5    0.1250    -9.927     1          44       0.0300
# 4650         0    5    0.0923   -15.332     1          47       0.0308
#
#        tempo  valence  cluster
# 3386  76.049    0.392       17
# 3402  78.788    0.956       17
# 3460  76.077    0.656       17
# 3481  71.448    0.348       17
# 4650  82.611    0.312       17
# ----------------------------------------------------------------------------------------------------
# Cluster 18
#                           id                          name  \
# 2628  7lN2ZGdAmVQFYvfBhrv0yK              Desesperadamente
# 2675  5yQgbjGfbj2U02m3M2wX3N             Stand by Your Man
# 2994  3GuUtxubpUewt8tckD79Bl        La Mujer Que Yo Quiero
# 3068  21YtaaAivXcpcFaYbTjgKP  To Be Young Gifted and Black
# 3072  5FD1IZKwXVSL3zGwlNvLoF                        Celoso
#
#                  artists  acousticness  danceability  energy  \
# 2628         Eydie Gormé         0.728         0.537   0.415
# 2675       Tammy Wynette         0.798         0.514   0.326
# 2994  Joan Manuel Serrat         0.613         0.551   0.492
# 3068        Bob & Marcia         0.418         0.646   0.454
# 3072        Roberto Luti         0.840         0.526   0.501
#
#       instrumentalness  explicit  key  liveness  loudness  mode  popularity  \
# 2628          0.000000         0    8     0.242   -12.961     1          37
# 2675          0.000760         0    9     0.153    -9.690     1          44
# 2994          0.000000         0    1     0.103    -7.188     0          41
# 3068          0.000532         0    0     0.353   -10.821     1          41
# 3072          0.000000         0    0     0.139    -8.088     1          39
#
#       speechiness    tempo  valence  cluster
# 2628       0.0338  112.958    0.833       18
# 2675       0.0291  106.504    0.559       18
# 2994       0.0288  116.490    0.733       18
# 3068       0.0308  117.125    0.922       18
# 3072       0.0367  113.546    0.762       18
# ----------------------------------------------------------------------------------------------------
# Cluster 19
#                           id  \
# 1688  6443igXMStgLhDvCveDZfQ
# 1759  5zTLkmFCtatsL66leWDzYu
# 1772  7Ip6RxnfiDWXO3kp4FAzlO
# 1817  66zvey9033Ttmtj09VfwF0
# 1843  2DHSI9LXjHAdPT8gc5ghbf
#
#                                                    name  \
# 1688                                 Lo Que Quiera Lola
# 1759  Italian Concerto in F Major, BWV 971: III. Pre...
# 1772                                    De Ti Enamorado
# 1817                                   Exactly Like You
# 1843                                       Proud Of You
#
#                     artists  acousticness  danceability  energy  \
# 1688             Bobby Capo         0.741         0.782   0.485
# 1759  Johann Sebastian Bach         0.978         0.263   0.339
# 1772    La Sonora Matancera         0.828         0.742   0.530
# 1817           Carmen McRae         0.601         0.694   0.353
# 1843          Eddie Cochran         0.678         0.506   0.420
#
#       instrumentalness  explicit  key  liveness  loudness  mode  popularity  \
# 1688          0.000122         0    0    0.3340   -11.593     1          19
# 1759          0.883000         0    5    0.1320   -19.828     1          19
# 1772          0.000000         0   10    0.0497   -11.410     1          24
# 1817          0.000000         0    5    0.1050    -7.713     1          21
# 1843          0.000000         0    1    0.2020    -9.640     1          18
#
#       speechiness    tempo  valence  cluster
# 1688       0.1490  133.127    0.799       19
# 1759       0.0323  141.828    0.902       19
# 1772       0.0409  137.160    0.973       19
# 1817       0.0437  135.258    0.563       19
# 1843       0.0481  141.016    0.859       19
# ----------------------------------------------------------------------------------------------------

# %%
df_new[df_new['artists'] == 'Bobby Capo']
# Out:
#                             id                         name     artists  \
# 1688    6443igXMStgLhDvCveDZfQ           Lo Que Quiera Lola  Bobby Capo
# 9805    0VntiMue6qOcWmJTDhCKXF  Luna De Miel En Puerto Rico  Bobby Capo
# 71596   0JaPsiY4rZB6g3dGoeYmiR                      El Cucú  Bobby Capo
# 137875  2M3YIKtGu9e3SQDcOdtPTB             Me Lo Dijo Adela  Bobby Capo
# 163416  2RaXEKmOuAwQ1NAXbsdbwU          Locamente Enamorado  Bobby Capo
#
#         acousticness  danceability  energy  instrumentalness  explicit  key  \
# 1688           0.741         0.782   0.485          0.000122         0    0
# 9805           0.834         0.746   0.394          0.003930         0    8
# 71596          0.817         0.644   0.383          0.000000         0    2
# 137875         0.774         0.848   0.593          0.000482         0    3
# 163416         0.867         0.664   0.367          0.000231         0    4
#
#         liveness  loudness  mode  popularity  speechiness    tempo  valence  \
# 1688      0.3340   -11.593     1          19       0.1490  133.127    0.799
# 9805      0.1190   -12.410     1          10       0.1450  131.573    0.826
# 71596     0.0691    -8.933     0           3       0.1790   95.119    0.804
# 137875    0.1030   -11.769     0          17       0.1200  135.878    0.963
# 163416    0.3820   -10.599     0          16       0.0501  113.680    0.867
#
#         cluster
# 1688         19
# 9805          6
# 71596        10
# 137875        6
# 163416        0
